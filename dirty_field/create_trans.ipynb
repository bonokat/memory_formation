# %%
import pyvistaqt
import mne

# %%
subs_dir = 'D:\\Ekaterina_Voevodina\\MRI_FS'
subject = 'Sub2_memform'

mne.gui.coregistration(subjects_dir=subs_dir, subject=subject)
# Out:
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with:
# pip install qdarkstyle
#
#     Triangle neighbors and vertex normals...
# Using high resolution head model in D:\Ekaterina_Voevodina\MRI_FS\Sub2_memform\surf\lh.seghead
#     Triangle neighbors and vertex normals...
# Using fiducials from: D:\Ekaterina_Voevodina\MRI_FS\Sub2_memform\bem\Sub2_memform-fiducials.fif.
#     Triangle neighbors and vertex normals...
# Using high resolution head model in D:\Ekaterina_Voevodina\MRI_FS\Sub2_memform\surf\lh.seghead
#     Triangle neighbors and vertex normals...
# Using fiducials from: D:\Ekaterina_Voevodina\MRI_FS\Sub2_memform\bem\Sub2_memform-fiducials.fif.
# ...

# %%
subs_dir = 'D:\\Ekaterina_Voevodina\\MRI_FS'
subject = 'Sub2_memform'
trans_path = 'D:\\Ekaterina_Voevodina\\MRI_FS\\Sub2_memform\\sub2-trans'
trans = trans = mne.read_trans(trans_path)
raw_path = 'D:\\Ekaterina_Voevodina\\memory_formation\\data\\subjects\\sub2\\raw\\Encoding1_tsss_mc_trans_annotated_filtered_reconstructed.fif'
raw = mne.io.read_raw_fif(raw_path)
# surfaces = dict(brain=0.4, outer_skull=0.6, head=None)

mne.viz.plot_alignment(
    info=raw.info, trans=trans,
    subject=subject, subjects_dir=subs_dir,
    surfaces='auto', coord_frame='head',
    dig=True, mri_fiducials=True,
    ) # Plot head, sensor, and source space alignment in 3D
# Out:
# Opening raw data file D:\Ekaterina_Voevodina\memory_formation\data\subjects\sub2\raw\Encoding1_tsss_mc_trans_annotated_filtered_reconstructed.fif...
#     Range : 75000 ... 1016999 =     75.000 ...  1016.999 secs
# Ready.
# C:\Users\CCDM\AppData\Local\Temp\ipykernel_10836\1563848771.py:6: RuntimeWarning: This filename (D:\Ekaterina_Voevodina\memory_formation\data\subjects\sub2\raw\Encoding1_tsss_mc_trans_annotated_filtered_reconstructed.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_path)
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# ...
